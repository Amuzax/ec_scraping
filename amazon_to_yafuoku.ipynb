# %% [markdown]
# # 案件
# - 【市場調査】Amazon/ヤフオクの市場の調査をお願いします。初心者歓迎/隙間時間にもできます
# - https://crowdworks.jp/public/jobs/9151993

# %% [markdown]
# # 課題
# - ● Amazon 情報を取れなかった商品は画像情報も取らないようにする。<br>
# →　ヤフオクの情報を取った時に画像も取れているので、Amazon 情報を取れなかったらヤフオク画像情報を消せればよい。<br>
# →　目視で消すんだったら画像を見るよりも「詳細」ビューにしてファイル名で見る方がラク。<br>
# →　2023/05/22：画像削除コード追加完了

# %% [markdown]
# # 動作検証

# %% [markdown]
# ## ヤフオク情報取得テスト

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from time import sleep
from bs4 import BeautifulSoup
import datetime
import csv
import pandas as pd

CHROMEDRIVER = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\chromedriver.exe'
chrome_service = fs.Service(executable_path = CHROMEDRIVER)
options = Options()
# options.add_argument('--headless')  # ヘッドレスモード
driver = webdriver.Chrome(service = chrome_service, options = options)

url = 'https://auctions.yahoo.co.jp/jp/show/rating?userID=k_h_112&role=seller'
driver.get(url)

# %%
# 下記の商品検索を経由せずに指定の商品ページを直接開く
url = 'https://page.auctions.yahoo.co.jp/jp/auction/s1087711376'
driver.get(url)

name = 'スピード メーター 140km /h 60mm トリップメーター 付 汎用品 ブラック'

# %%
# 一覧ページの HTML 構造を取得する
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# 各商品の親要素を取得する
items = soup.select('td[colspan] > table[bgcolor="#ffffff"]')

# 取得結果の格納用リストを準備する
yafuoku_item_list = []

# %%
for item in items:

    detail_url = item.select('a')[0]['href']
    print(detail_url)

    name = item.select('a')[0].text.rstrip()
    print(name)

    eval_date = item.select('td[width="98%"] small')[0].text.splitlines()[1].replace(')', '').split('：')[1]
    print(eval_date)

# %%
# 詳細ページを開く
driver.get(detail_url)

# %%
# 詳細ページの HTML 構造を取得する
soup_detail = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# 価格
price = soup_detail.select('dd.Price__value')[0].text.strip()
print(price)

# %%
# 最初に表示されている画像を保存する
# ● 商品名に「/」などのファイル名使用不可文字が入っていると画像保存できない
# →　name.replace('/', '／') などとして商品名から該当文字を置き換えるか取り除く。Amazon商品名も同じ処理をする
import shutil
import os
import requests

image_url = soup_detail.select(f'div.ProductImage__inner img[alt*="{name}"]')[0]['src']
print(image_url)

path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\images'
file_name = name.replace('/', '／').replace(':', '：') + '【ヤフオク】.' + image_url.split('.')[-1]
print(file_name)
file_path = os.path.join(path, file_name)
print(file_path)

response = requests.get(image_url, stream=True)

with open(file_path, 'wb') as file:
    shutil.copyfileobj(response.raw, file)

# %%
# 送料の詳細ポップアップを開く
driver.find_element(By.ID, 'postageDetailCurrent').click()

# %%
# ポップアップの中から送料を取得する　→　送料を取れるようになった！！！
postage = soup_detail.select('div.BidModal__postagePrice')[0].text
print(postage)

# %%
# ポップアップを閉じる
driver.find_element(By.XPATH, '//a[@class="BidModal__hideButton BidModal__hideButton--large js-modal-hide cl-nofollow"]').click()

# %%
# 取得した情報をリストに追加する
yafuoku_item_list.append([name, price, postage, eval_date, detail_url])
sleep(1)

# %%
# 取得結果を保存する
csv_header = ['商品名', '価格', '送料', '評価日時', '商品ページURL']
csv_date = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
csv_file_name = 'ヤフオクデータ_' + csv_date + '.csv'

with open(csv_file_name, 'w', errors = 'ignore') as file:
    writer = csv.writer(file, lineterminator='\n')
    writer.writerow(csv_header)
    writer.writerows(yafuoku_item_list)

# %%
print(soup.select('a:contains("次の25件")')[0]['href'])

# %%
driver.find_element(By.XPATH, '(//a[contains(text(),"次の25件")])[1]').click()

# %%
# 待ち時間テスト
print('driver.implicitly_wait(5) 開始')
driver.implicitly_wait(5)
print('driver.implicitly_wait(5) 終了')

# %% [markdown]
# ## Amazon情報取得テスト

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from time import sleep
from bs4 import BeautifulSoup
import datetime
import csv
import pandas as pd

CHROMEDRIVER = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\chromedriver.exe'
chrome_service = fs.Service(executable_path = CHROMEDRIVER)
options = Options()
# options.add_argument('--headless')  # ヘッドレスモード
driver = webdriver.Chrome(service = chrome_service, options = options)

# Amazon のトップページを開く
url = 'https://www.amazon.co.jp/ref=nav_logo'
driver.get(url)

# %%
# 下記の商品検索を経由せずに指定の商品ページを直接開く
url = 'https://www.amazon.co.jp/Honda-%E3%82%AF%E3%83%A9%E3%82%B7%E3%83%83%E3%82%AF-%E3%82%A8%E3%83%B3%E3%83%96%E3%83%AC%E3%83%A0-215mm%C3%9723mm-%E3%83%AA%E3%83%88%E3%83%AB%E3%82%AB%E3%83%96/dp/B00LVCMEH8/ref=sr_1_2?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=20GQXC9YDP57D&keywords=Honda+%E3%82%AF%E3%83%A9%E3%82%B7%E3%83%83%E3%82%AF+%E3%82%A8%E3%83%B3%E3%83%96%E3%83%AC%E3%83%A0+%E3%83%A1%E3%83%83%E3%82%AD+%E7%AD%86%E8%A8%98%E4%BD%93+215mm%C3%9723mm+%E3%83%9B%E3%83%B3%E3%83%80+%E3%83%A2%E3%83%B3%E3%82%AD%E3%83%BC+%E3%82%B4%E3%83%AA%E3%83%A9+%E3%82%A8%E3%82%A4%E3%83%97+%E3%82%B7%E3%83%A3%E3%83%AA%E3%83%BC+%E3%83%80%E3%83%83%E3%82%AF%E3%82%B9+%E3%83%87%E3%82%A3%E3%82%AA+%E3%82%BA%E3%83%BC%E3%83%9E%E3%83%BC+%E3%83%AA%E3%83%88%E3%83%AB%E3%82%AB%E3%83%96&qid=1681913537&sprefix=honda+%E3%82%AF%E3%83%A9%E3%82%B7%E3%83%83%E3%82%AF+%E3%82%A8%E3%83%B3%E3%83%96%E3%83%AC%E3%83%A0+%E3%83%A1%E3%83%83%E3%82%AD+%E7%AD%86%E8%A8%98%E4%BD%93+215mm+23mm+%E3%83%9B%E3%83%B3%E3%83%80+%E3%83%A2%E3%83%B3%E3%82%AD%E3%83%BC+%E3%82%B4%E3%83%AA%E3%83%A9+%E3%82%A8%E3%82%A4%E3%83%97+%E3%82%B7%E3%83%A3%E3%83%AA%E3%83%BC+%E3%83%80%E3%83%83%E3%82%AF%E3%82%B9+%E3%83%87%E3%82%A3%E3%82%AA+%E3%82%BA%E3%83%BC%E3%83%9E%E3%83%BC+%E3%83%AA%E3%83%88%E3%83%AB%E3%82%AB%E3%83%96%2Caps%2C463&sr=8-2'
driver.get(url)

# %%
yafuoku_name = 'ピクチャーレール用 ステンレスワイヤー 吊り下げ金具 シルバー 4本セット (0.5m フック1個)'
# yafuoku_name = 'Sweetwinds ペニスリング コックリング 二重リング 日本人サイズ 柔らかいシリコン 高弾力 男性用オナニーリング アダル'

# 検索窓に商品名を入力して検索する
driver.find_element(By.ID, 'twotabsearchtextbox').send_keys(yafuoku_name)
driver.find_element(By.ID, 'nav-search-submit-button').click()

# %%
# アダルト商品の場合、年齢確認のポップアップ（新ウィンドウ）が表示されるので「はい」をクリックする
# ただしアダルト商品はそもそもヤフオクで取得できていない
try:
    # 商品ページのリンクをクリックする。新ウィンドウで開かれる
    driver.find_element(By.XPATH, f'(//span[contains(text(),"{yafuoku_name}")]/parent::a[@target="_blank"])[1]').click()
    sleep(1)
except:
    # 年齢認証のポップアップで「はい」を選択する
    driver.find_element(By.ID, 'a-autoid-1-announce').click()
    sleep(1)
    # 商品ページのリンクをクリックする。新ウィンドウで開かれる
    driver.find_element(By.XPATH, f'(//span[contains(text(),"{yafuoku_name}")]/parent::a[@target="_blank"])[1]').click()
    sleep(1)

# %%
# 開いているすべてのウィンドウハンドルを取得する（リスト形式）
handle_array = driver.window_handles
# 新ウィンドウに切り替える
driver.switch_to.window(handle_array[-1])
# 新ウィンドウの HTML 構造を取得する
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
amazon_name = soup.select('span#productTitle')[0].text.strip()
print('Amazon商品名:', amazon_name)

try:
    amazon_price = soup.select('div#corePrice_feature_div span.a-price-whole')[0].text
except:
    amazon_price = soup.select('span#snsDetailPagePrice > span#sns-base-price')[0].text.strip().split()[0]
print('Amazon価格:', amazon_price)

try:
    amazon_tax = soup.select('div#corePrice_feature_div span#taxInclusiveMessage')[0].text.strip().replace('税込', '0')
except:
    amazon_tax = soup.select('span#snsDetailPagePrice > span#sns-base-price > span')[0].text.strip().replace('税込', '0')
print('Amazon税金:', amazon_tax)

amazon_postage = soup.select('span[data-csa-c-content-id="DEXUnifiedCXPDM"]')[0].text.lstrip().replace('配送料 ', '').replace('詳細を見る', '')
print('Amazon送料:', amazon_postage)

amazon_delivery_date = soup.select('div#mir-layout-DELIVERY_BLOCK span.a-text-bold')[0].text.replace(' ', "")
print('Amazon着日:', amazon_delivery_date)

amazon_stock = soup.select('div#availability > span')[0].text.strip()
print('Amazon在庫:', amazon_stock)

amazon_url = driver.current_url
print('Amazon商品URL:', amazon_url)

amazon_info_get_date = datetime.datetime.now()
print('Amazon情報取得日:', amazon_info_get_date)

# %%
# 最初に表示されている画像を保存する
# ● 商品名に「/」「:」などのファイル名使用不可文字が入っていると画像保存できない
# →　yafuoku_name.replace('/', '／') などとして商品名から該当文字を置き換えるか取り除く。ヤフオク商品名も同じ処理をする
import shutil
import os
import requests

image_url = soup.select(f'div#imgTagWrapperId > img[alt*="{yafuoku_name}"]')[0]['src']
print('image_url:', image_url)

path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\images'
file_name = yafuoku_name.replace('/', '／').replace(':', '：') + '【Amazon】.' + image_url.split('.')[-1]
print('file_name:', file_name)
file_path = os.path.join(path, file_name)
print('file_path:', file_path)

response = requests.get(image_url, stream=True)

with open(file_path, 'wb') as file:
    shutil.copyfileobj(response.raw, file)

# %%
# ヤフオク画像削除
import glob
import os

path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\images'
remove_file = 'ダイヤ(DAIYA) ベーシックパット TR-433【ヤフオク】 - コピー' + '.jpg'
remove_file_path = os.path.join(path, remove_file)
print('remove_file_path:', remove_file_path)
os.remove(remove_file_path)

# %% [markdown]
# ## 画像比較テスト

# %%
# 【Python】OpenCVとNumPyで２つの画像を比較（完全一致、部分一致の比率）
# https://office54.net/python/module/opencv-numpy-compare

import cv2
import numpy as np

image1 = cv2.imread('office54.png')
image2 = cv2.imread('office54.png')
image3 = cv2.imread('office54-eng.png')

print(np.array_equal(image1, image2))
print(np.array_equal(image1, image3))
# True
# False

# 画像をリサイズする
img_size = (100, 100)
image1 = cv2.resize(image1, img_size)
image2 = cv2.resize(image2, img_size)
image3 = cv2.resize(image3, img_size)

# 画像をヒストグラム化する
image1_hist = cv2.calcHist([image1], [0], None, [256], [0, 256])
image2_hist = cv2.calcHist([image2], [0], None, [256], [0, 256])
image3_hist = cv2.calcHist([image3], [0], None, [256], [0, 256])

# ヒストグラムした画像を比較
print(cv2.compareHist(image1_hist, image2_hist, 0))
print(cv2.compareHist(image1_hist, image3_hist, 0))
# 1.0
# 0.8882466100801328

# %%
# 【Python】画像の類似度比較が可能なImageHashのインストール
# https://self-development.info/%E3%80%90python%E3%80%91%E7%94%BB%E5%83%8F%E3%81%AE%E9%A1%9E%E4%BC%BC%E5%BA%A6%E6%AF%94%E8%BC%83%E3%81%8C%E5%8F%AF%E8%83%BD%E3%81%AAimagehash%E3%81%AE%E3%82%A4%E3%83%B3%E3%82%B9%E3%83%88%E3%83%BC/

from PIL import Image
import imagehash

# Y_hash = imagehash.average_hash(Image.open('フォグランプ_ヤフオク.jpg'))
Y_hash = imagehash.average_hash(Image.open('ベアリング_ヤフオク.jpg'))
print(Y_hash)

# A_hash = imagehash.average_hash(Image.open('フォグランプ_Amazon.jpg'))
A_hash = imagehash.average_hash(Image.open('ベアリング_Amazon.jpg'))
print(A_hash)

print(Y_hash == A_hash)
print(Y_hash - A_hash)

# %%
from PIL import Image
import imagehash
import os

path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping'

# Y_name = 'ベアリング_ヤフオク.jpg'
Y_name = 'フォグランプ_ヤフオク.jpg'
Y_path = os.path.join(path, Y_name)
Y_hash = imagehash.average_hash(Image.open(Y_path))
print('Y_hash:', Y_hash)

A_name = 'ベアリング_Amazon.jpg'
# A_name = 'フォグランプ_Amazon.jpg'
A_path = os.path.join(path, A_name)
A_hash = imagehash.average_hash(Image.open(A_path))
print('A_hash:', A_hash)

print('hash完全一致度:', Y_hash == A_hash)
print('hash差:', Y_hash - A_hash)

# %% [markdown]
# # 完成版
# 1. ヤフオクから情報を取得する
# 1. ヤフオクで取得した情報を基に Amazon で検索する

# %% [markdown]
# ## 1.ヤフオクの情報を取得する

# %% [markdown]
# 調査対象セラーの URL（SnC23様提供情報）
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=cawjz38692&slider=undefined
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=k_h_112&role=seller # 商品名完全一致
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=mlamb63401&role=seller # 商品名完全一致
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=usaginokono&slider=undefined
#
# 調査対象セラーの URL（下遠野調査結果）
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=wanwanwankonabe # 商品名部分一致 実績多い
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=ebnq4452 # 商品名完全一致あり 実績少ない
# - https://auctions.yahoo.co.jp/seller/kaz_type_r_0227 # 実績古い
# - https://auctions.yahoo.co.jp/jp/show/rating?userID=fsflm19105&role=seller # 商品名完全一致あり やや少ない

# %%
'''
# %%time
# 2125件：Wall time: 2h 14min 6s
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from time import sleep
from bs4 import BeautifulSoup
import sys
import datetime
import csv
import pandas as pd
import shutil # 画像保存に使う
import os # 画像保存に使う
import requests # 画像保存に使う

CHROMEDRIVER = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\chromedriver.exe'
chrome_service = fs.Service(executable_path = CHROMEDRIVER)
options = Options()
# options.add_argument('--headless')  # ヘッドレスモード
driver = webdriver.Chrome(service = chrome_service, options = options)

# 調査対象ページ
url = 'https://auctions.yahoo.co.jp/jp/show/rating?userID=usaginokono&slider=undefined'

# 画像保存用フォルダ
path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\images'

# 取得結果の格納用リストを準備する
yafuoku_item_list = []

# 「次の25件」のクリックを指定回数繰り返す
for i in range(1):
    driver.get(url)
    driver.implicitly_wait(3)

    # 一覧ページの HTML 構造を取得する
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # 各商品情報の親要素を取得する
    items = soup.select('td[colspan] > table[bgcolor="#ffffff"]')

    # 一覧ページ内の商品情報をすべて取得する
    for index, item in enumerate(items):
        try:
            print(f'{i+1}ページ目-{index+1}')

            # 商品名　一覧ページから取得
            name = item.select('a')[0].text.rstrip()
            print(name)

            # 評価日　一覧ページから取得
            # eval_date = item.select('td[width="98%"] small')[0].text.splitlines()[1]
            eval_date = item.select('td[width="98%"] small')[0].text.splitlines()[1]
            # print(eval_date)

            # 詳細ページへの URL　一覧ページから取得
            detail_url = item.select('a')[0]['href']
            # print(detail_url)

            # 詳細ページを開く
            # ■ アダルトカテゴリを開こうとすると年齢認証（ログイン認証）が走り取得できない
            driver.get(detail_url)

            # 詳細ページの HTML 構造を取得する
            soup_detail = BeautifulSoup(driver.page_source, 'html.parser')

            # 価格　詳細ページから取得
            price = soup_detail.select('dd.Price__value')[0].text.strip()
            # print(price)

            # 入札件数　詳細ページから取得
            bid_num = soup_detail.select('span:contains("件")')[0].text
            # print(bid_num)

            # 最初に表示されている画像　詳細ページから取得
            image_url = soup_detail.select(f'div.ProductImage__inner img[alt*="{name}"]')[0]['src']
            # print(image_url)
            file_name = name.replace('/', '／').replace(':', '：') + '【ヤフオク】.' + image_url.split('.')[-1]
            # print(file_name)
            file_path = os.path.join(path, file_name)
            # print(file_path)
            response = requests.get(image_url, stream=True)
            with open(file_path, 'wb') as file:
                shutil.copyfileobj(response.raw, file)

            # 送料の詳細ポップアップを開く
            driver.find_element(By.ID, 'postageDetailCurrent').click()
            driver.implicitly_wait(5)
            # ポップアップの中から送料を取得する　→　送料を取れるようになった！！！
            postage = soup_detail.select('div.BidModal__postagePrice')[0].text
            # print(postage)

            # 送料ポップアップを閉じる
            driver.find_element(By.XPATH, '//a[@class="BidModal__hideButton BidModal__hideButton--large js-modal-hide cl-nofollow"]').click()
            driver.implicitly_wait(5)

            # 取得した情報をリストに追加する
            yafuoku_item_list.append([name, price, postage, bid_num, eval_date, detail_url, image_url])
            # print('● 取得に成功しました ●')
        except:
            # 取得した情報をリストに追加する
            yafuoku_item_list.append([name, '【取得不可】', '【取得不可】', '【取得不可】', eval_date, detail_url, image_url])
            print('◆ 取得に失敗しました ◆')

    # 次のページがある場合は開く。ない場合は処理を終了する
    try:
        url = soup.select('a:contains("次の25件")')[0]['href']
        driver.implicitly_wait(5)
    except:
        driver.quit()
        break

# 取得結果を保存する
csv_header = ['商品名', '価格', '送料', '入札件数', '評価日', '商品ページURL', '画像URL']
csv_date = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
csv_file_name = 'ヤフオクデータ_' + csv_date + '.csv'

with open(csv_file_name, 'w', errors = 'ignore') as file:
    writer = csv.writer(file, lineterminator='\n')
    writer.writerow(csv_header)
    writer.writerows(yafuoku_item_list)

print('----- ヤフオク情報取得完了 -----')

# %%
# %%time
# 2125件：Wall time: 2h 14min 6s
# 2023/06/17：各項目の取得を個別の try - except に分割
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from time import sleep
from bs4 import BeautifulSoup
import sys
import datetime
import csv
import pandas as pd
import shutil # 画像保存に使う
import os # 画像保存に使う
import requests # 画像保存に使う

CHROMEDRIVER = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\chromedriver.exe'
chrome_service = fs.Service(executable_path = CHROMEDRIVER)
options = Options()
# options.add_argument('--headless')  # ヘッドレスモード
driver = webdriver.Chrome(service = chrome_service, options = options)

# 調査対象ページ
url = 'https://auctions.yahoo.co.jp/jp/show/rating?userID=usaginokono&slider=undefined'

# 画像保存用フォルダ
path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images'

# 取得結果の格納用リストを準備する
yafuoku_item_list = []

# 「次の25件」のクリックを指定回数繰り返す
for i in range(1):
    driver.get(url)
    driver.implicitly_wait(3)

    # 一覧ページの HTML 構造を取得する
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # 各商品情報の親要素を取得する
    items = soup.select('td[colspan] > table[bgcolor="#ffffff"]')

    # 一覧ページ内の商品情報をすべて取得する
    for index, item in enumerate(items):
        print(f'■■■■■ {i+1}ページ目-{index+1} ■■■■■')

        try:
            # 商品名　を一覧ページから取得
            name = item.select('a')[0].text.rstrip()
        except:
            name = '◆取得失敗◆'
        finally:
            print('ヤフオク商品名：', name)

        try:
            # 評価日　を一覧ページから取得
            # eval_date = item.select('td[width="98%"] small')[0].text.splitlines()[1]
            eval_date = item.select('td[width="98%"] small')[0].text.splitlines()[1].replace(')', '').split('：')[1]
        except:
            eval_date = '◆取得失敗◆'
        finally:
            print('評価日：', eval_date)

        try:
            # 詳細ページへの URL を一覧ページから取得して開く
            # ■ アダルトカテゴリを開こうとすると年齢認証（ログイン認証）が走り取得できない
            detail_url = item.select('a')[0]['href']
            driver.get(detail_url)

            # 詳細ページの HTML 構造を取得する
            soup_detail = BeautifulSoup(driver.page_source, 'html.parser')
        except:
            detail_url = '◆取得失敗◆'
        finally:
            print('商品URL：', detail_url)

        try:
            # 価格　詳細ページから取得
            price = soup_detail.select('dd.Price__value')[0].text.strip().replace(',', '').replace('円', '').replace(' ', '')
        except:
            price = '◆取得失敗◆'
        finally:
            print('価格：', price)

        try:
            # 入札件数　詳細ページから取得
            bid_num = soup_detail.select('a > span:contains("件")')[0].text.replace('件', '')
        except:
            bid_num = '◆取得失敗◆'
        finally:
            print('入札件数：', bid_num)

        try:
            # 最初に表示されている画像　詳細ページから取得
            image_url = soup_detail.select(f'div.ProductImage__inner img[alt*="{name}"]')[0]['src']
            file_name = name.replace('/', '／').replace(':', '：').replace('?', '：') + '【ヤフオク】.' + image_url.split('.')[-1]
            file_path = os.path.join(path, file_name)
            response = requests.get(image_url, stream=True)
            with open(file_path, 'wb') as file:
                shutil.copyfileobj(response.raw, file)
        except:
            image_url = '◆取得失敗◆'
            file_name = '◆取得失敗◆'
            file_path = '◆取得失敗◆'
        finally:
            print('画像URL：', image_url)
            print('画像ファイル名：', file_name)
            print('画像ファイルパス：', file_path)

        try:
            # 送料の詳細ポップアップを開く
            driver.find_element(By.ID, 'postageDetailCurrent').click()
            driver.implicitly_wait(3)
            # ポップアップの中から送料を取得する　→　送料を取れるようになった！！！
            postage = soup_detail.select('div.BidModal__postagePrice')[0].text.replace('円', '')

            # 送料ポップアップを閉じる
            driver.find_element(By.XPATH, '//a[@class="BidModal__hideButton BidModal__hideButton--large js-modal-hide cl-nofollow"]').click()
            driver.implicitly_wait(3)
        except:
            postage = '◆取得失敗◆'
        finally:
            print('送料', postage)

        # 取得した情報をリストに追加する
        yafuoku_item_list.append([name, price, postage, bid_num, eval_date, detail_url, image_url])

    # 次のページがある場合は開く。ない場合は処理を終了する
    try:
        url = soup.select('a:contains("次の25件")')[0]['href']
        driver.implicitly_wait(3)
    except:
        driver.quit()
        break

# 取得結果を保存する
csv_header = ['商品名', '価格', '送料', '入札件数', '評価日', '商品ページURL', '画像URL']
csv_date = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
csv_file_name = 'ヤフオクデータ_' + csv_date + '.csv'

with open(csv_file_name, 'w', errors = 'ignore') as file:
    writer = csv.writer(file, lineterminator='\n')
    writer.writerow(csv_header)
    writer.writerows(yafuoku_item_list)

print('----- ヤフオク情報取得完了 -----')

# %% [markdown]
# ## 2.ヤフオクの取得データを基に Amazon の情報を検索する

# %% [markdown]
# ■ 詳細ページのURLをクリックするのではなく、Selenium(?)を使って詳細ページのURLを開く方法にすれば別ウィンドウとしては開かれない。

# %%
# %%time
# 283件：Wall time: 27min 54s # sleep(1)
# 376件：Wall time: 49min 25s # sleep(2) に延長
# 500件：Wall time: 1h 10min 32s
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome import service as fs
from time import sleep
from bs4 import BeautifulSoup
import datetime
import csv
import pandas as pd
import shutil # 画像保存に使う
import os # 画像保存に使う
import requests # 画像保存に使う
import glob # ヤフオク画像削除に使う
from PIL import Image # 画像比較に使う
import imagehash # 画像比較に使う

CHROMEDRIVER = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\chromedriver.exe'
chrome_service = fs.Service(executable_path = CHROMEDRIVER)
options = Options()
# options.add_argument('--headless')  # ヘッドレスモード
driver = webdriver.Chrome(service = chrome_service, options = options)

# Amazon のトップページを開く
url = 'https://www.amazon.co.jp/ref=nav_logo'
driver.get(url)
driver.implicitly_wait(5)

# 大元のウィンドウハンドラの保持
original_window = driver.current_window_handle

# ヤフオクデータ csv の取得
df = pd.read_csv('ヤフオクデータ_20230617-160803.csv', encoding='cp932')

# 画像保存用フォルダ
path = r'C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images'

# 取得情報格納用のリスト準備
yafuoku_amazon_list = []

for index, yafuoku_item in df.iterrows():
    print(f'■■■■■■■■■■■■■■■ {index+1} / {len(df)} ■■■■■■■■■■■■■■■')

    # 取得済のヤフオク関連情報を取得する
    try:
        yafuoku_name = yafuoku_item['商品名']
        print('ヤフオク商品名:', yafuoku_name)

        yafuoku_price = yafuoku_item['価格'].replace('円（税込 ', '／税込').replace('円（税 ', '／').replace(' 円）', '').split('／')[0]
        print('ヤフオク価格:', yafuoku_price)
        
        if '税込' in yafuoku_item['価格']:
            yafuoku_tax = 0
        else:
            yafuoku_tax = yafuoku_item['価格'].replace('円（税込 ', '／税込').replace('円（税 ', '／').replace(' 円）', '').split('／')[1]
        print('ヤフオク税金:', yafuoku_tax)

        yafuoku_postage = yafuoku_item['送料'].replace('円（税込）', '')
        print('ヤフオク送料:', yafuoku_postage)
        
        yafuoku_bid_num = yafuoku_item['入札件数']
        # yafuoku_bid_num = yafuoku_item['入札件数'].replace('件', '')
        print('ヤフオク入札件数:', yafuoku_bid_num)

        yafuoku_eval_date = yafuoku_item['評価日']
        # yafuoku_eval_date = yafuoku_item['評価日'].replace('(評価日時：', '').replace(')', '')
        print('ヤフオク評価日:', yafuoku_eval_date)

        yafuoku_url = yafuoku_item['商品ページURL']
        print('ヤフオク商品URL:', yafuoku_url)
        
        yafuoku_image_url = yafuoku_item['画像URL']
        print('ヤフオク商品URL:', yafuoku_image_url)
    except:
        print('◆ヤフオク情報取得失敗◆')

    try:
        # 検索ボックスに商品名を入力する
        driver.find_element(By.ID, 'twotabsearchtextbox').send_keys(yafuoku_name)
        # 検索ボタンをクリックする
        driver.find_element(By.ID, 'nav-search-submit-button').click()
        driver.implicitly_wait(3)

        try:
            # 商品ページのリンクをクリックする。新ウィンドウで開かれる
            driver.find_element(By.XPATH, f'(//span[contains(text(),"{yafuoku_name}")]/parent::a[@target="_blank"])[1]').click()
            driver.implicitly_wait(3)
        except:
            # アダルト商品の場合、年齢確認のポップアップ（新ウィンドウ）が表示されるので「はい」をクリックする
            driver.find_element(By.ID, 'a-autoid-1-announce').click()
            driver.implicitly_wait(3)
            # 商品ページのリンクをクリックする。新ウィンドウで開かれる
            driver.find_element(By.XPATH, f'(//span[contains(text(),"{yafuoku_name}")]/parent::a[@target="_blank"])[1]').click()
            driver.implicitly_wait(3)
            
        # 開いているすべてのウィンドウハンドルを取得する（リスト形式で返ってくる）
        handle_array = driver.window_handles
        # 新ウィンドウに切り替える
        driver.switch_to.window(handle_array[-1])
        # 新ウィンドウの HTML 構造を取得する
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        amazon_name = soup.select('span#productTitle')[0].text.strip()
        # print('Amazon商品名:', amazon_name)

        try:
            amazon_price = soup.select('div#corePrice_feature_div span.a-offscreen')[0].text.replace(',', '').replace('￥', '') # 定期オトク便がある場合の通常の注文価格
        except:
            amazon_price = soup.select('div#corePrice_feature_div span.a-price-whole')[0].text.replace(',', '').replace('￥', '') # ページ右側の枠内の価格（定期便なし）
            # amazon_price = soup.select('span#snsDetailPagePrice > span#sns-base-price')[0].text.strip().split()[0] # 商品画像右側の各区
        print('Amazon価格:', amazon_price)

        try:
            amazon_tax = soup.select('div#corePrice_feature_div span#taxInclusiveMessage')[0].text.strip().replace('税込', '0')
        except:
            amazon_tax = soup.select('span#snsDetailPagePrice > span#sns-base-price > span')[0].text.strip().replace('税込', '0')
        finally:
            print('Amazon税金:', amazon_tax)

        try:
            amazon_postage = soup.select('span[data-csa-c-content-id="DEXUnifiedCXPDM"]')[0].text.strip().replace('無料配送', '0／').replace('詳細を見る', '')
            # amazon_postage = soup.select('span[data-csa-c-content-id="DEXUnifiedCXPDM"]')[0].text.strip().replace('詳細を見る', '')
            amazon_delivery_date = soup.select('div#mir-layout-DELIVERY_BLOCK span.a-text-bold')[0].text.replace(' ', '')
            amazon_stock = soup.select('div#availability > span')[0].text.strip().replace(' ご注文はお早めに', '').replace('。', '')
            amazon_url = driver.current_url
        except:
            amazon_postage = '◆取得失敗◆'
            amazon_delivery_date = '◆取得失敗◆'
            amazon_stock = '◆取得失敗◆'
            amazon_url = '◆取得失敗◆'
        finally:
            print('Amazon送料:', amazon_postage)
            print('Amazon着日:', amazon_delivery_date)
            print('Amazon在庫:', amazon_stock)
            print('Amazon商品URL:', amazon_url)

        # 最初に表示されている画像を取得する
        try:
            amazon_image_url = soup.select(f'div#imgTagWrapperId > img[alt*="{yafuoku_name}"]')[0]['src']
            amazon_image_name = yafuoku_name.replace('/', '／').replace(':', '：').replace('?', '：') + '【Amazon】.' + amazon_image_url.split('.')[-1]
            amazon_image_path = os.path.join(path, amazon_image_name)
            response = requests.get(amazon_image_url, stream=True)
            with open(amazon_image_path, 'wb') as file:
                shutil.copyfileobj(response.raw, file)
                # print('画像を保存しました')
        except:
            amazon_image_url = '◆取得失敗◆'
            amazon_image_name = yafuoku_name.replace('/', '／').replace(':', '：').replace('?', '：') + '【Amazon】.' + amazon_image_url.split('.')[-1]
            amazon_image_path = os.path.join(path, amazon_image_name)
        finally:
            print('Amazon画像URL:', amazon_image_url)
            print('Amazon画像ファイル名:', amazon_image_name)
            print('Amazon画像ファイルパス:', amazon_image_path)
        
        # ヤフオク画像とAmazon画像の一致度を判定する
        yafuoku_image_name = amazon_image_name.replace('【Amazon】', '【ヤフオク】')

        yafuoku_image_path = os.path.join(path, yafuoku_image_name)
        amazon_image_path = os.path.join(path, amazon_image_name)
        
        yafuoku_image_hash = imagehash.average_hash(Image.open(yafuoku_image_path))
        amazon_image_hash = imagehash.average_hash(Image.open(amazon_image_path))
        
        hash_diff = yafuoku_image_hash - amazon_image_hash
        # print('hash_diff:', hash_diff)
        
        # 取得した情報をリストに追加する
        yafuoku_amazon_list.append([
            yafuoku_name, yafuoku_price, yafuoku_tax, yafuoku_postage, yafuoku_bid_num, yafuoku_eval_date, yafuoku_url, yafuoku_image_url, \
            amazon_name, amazon_price, amazon_tax, amazon_postage, amazon_delivery_date, amazon_stock, amazon_url, amazon_image_url, \
            f'=IF(COUNTIF(I{index+2},A{index+2}&"*"),"一致","不一致")', \
            hash_diff, \
            f'=COUNTIF($A$2:A{index+2},A{index+2})', \
            f'=COUNTIF($I$2:I{index+2},I{index+2})', \
            f'=(B{index+2}+D{index+2})*0.9-(J{index+2}+L{index+2})'
        ])

        # 現在のウィンドウを閉じる
        driver.close()
        driver.implicitly_wait(5)

        # ウィンドウハンドラを大元のウィンドウに切り替える
        driver.switch_to.window(original_window)

        # 検索ボックスに残っている文字列を消す
        driver.find_element(By.ID, 'twotabsearchtextbox').clear()
    except:
        # 取得したヤフオク画像を削除する　2023/05/22追加　拡張子の柔軟性はないがひとまず動くようにはできた
        
#         yafuoku_image_name = yafuoku_name.replace('/', '／').replace(':', '：') + '【ヤフオク】.jpg'
#         remove_file_path = os.path.join(path, yafuoku_image_name)
#         os.remove(remove_file_path)

        print(f'◆Amazon情報取得失敗◆ ヤフオク画像 {yafuoku_image_name} 削除完了')

#     finally:
#         # 取得した情報をリストに追加する
#         yafuoku_amazon_list.append([
#         yafuoku_name, yafuoku_price, yafuoku_tax, yafuoku_postage, yafuoku_bid_num, yafuoku_eval_date, yafuoku_url, yafuoku_image_url, \
#         amazon_name, amazon_price, amazon_tax, amazon_postage, amazon_delivery_date, amazon_stock, amazon_url, amazon_image_url, \
#         f'=IF(COUNTIF(I{index+2},A{index+2}&"*"),"一致","不一致")', \
#         hash_diff, \
#         f'=COUNTIF($A$2:A{index+2},A{index+2})', \
#         f'=COUNTIF($I$2:I{index+2},I{index+2})', \
#         f'=(B{index+2}+D{index+2})*0.9-(J{index+2}+L{index+2})'
        
        yafuoku_amazon_list.append([
            yafuoku_name, yafuoku_price, yafuoku_tax, yafuoku_postage, yafuoku_bid_num, yafuoku_eval_date, yafuoku_url, yafuoku_image_url, \
            '【取得不可】', '-', '-', '-', '-', '-', '-', '-', \
            '-', \
            '-', \
            '-', \
            '-', \
            '-'
        ])
        
        # 検索ボックスに残っている文字列を消す
        driver.find_element(By.ID, 'twotabsearchtextbox').clear()

# 取得した全データを csv ファイルに出力する
csv_header = [
    'ヤフオク商品名', 'ヤフオク価格(税込)', 'ヤフオク税金', 'ヤフオク送料(税込)', 'ヤフオク入札件数', 'ヤフオク評価日', 'ヤフオク商品URL', 'ヤフオク画像URL', \
    'Amazon商品名', 'Amazon価格(税込)', 'Amazon税金','Amazon送料(税込)' ,'Amazon着日' ,'Amazon在庫' ,'Amazon商品URL' , 'Amazon画像URL' , \
    '商品名前方一致', \
    '画像整合性', \
    'ヤフオク商品名重複', \
    'Amazon商品名重複', \
    '差額'
]
csv_date = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
csv_file_name = 'ヤフオク＋Amazon調査結果_' + csv_date + '.csv'

with open(csv_file_name, 'w', errors = 'ignore') as file:
    writer = csv.writer(file, lineterminator='\n')
    writer.writerow(csv_header)
    writer.writerows(yafuoku_amazon_list)
    
print('----- Amazon情報取得完了 -----')
# Out:
# ■■■■■■■■■■■■■■■ 1 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 洗濯 物干し ハンガー マイランドリー2 ワイヤー ブルー 10連ハンガー 傾かず 干せる
# ヤフオク価格: 1550（税込1704）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/1080155589
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0401/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x449-1675024357ecok3b209539.jpg
# ◆Amazon情報を取得できませんでした。関連画像 高儀 斬丸 草刈用 ナイロンコードカッター ベーシック TD-B【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 2 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: エーモン ダブルコード 0.5sq 6m 黒/白ライン E537
# ヤフオク価格: 556（税込611）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/w1091002761
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1683410752uonri9237955.jpg
# Amazon価格: 329
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）（7 時間 11 分以内にご注文の場合）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%82%A8%E3%83%BC%E3%83%A2%E3%83%B3-%E3%83%80%E3%83%96%E3%83%AB%E3%82%B3%E3%83%BC%E3%83%89-0-5sq-%E7%99%BD%E3%83%A9%E3%82%A4%E3%83%B3-E537/dp/B003CIN6XA/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=1YQFIINPLHI55&keywords=%E3%82%A8%E3%83%BC%E3%83%A2%E3%83%B3+%E3%83%80%E3%83%96%E3%83%AB%E3%82%B3%E3%83%BC%E3%83%89+0.5sq+6m+%E9%BB%92%2F%E7%99%BD%E3%83%A9%E3%82%A4%E3%83%B3+E537&qid=1686988087&sprefix=%E3%82%A8%E3%83%BC%E3%83%A2%E3%83%B3%2Caps%2C223&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/61iIKXmtnQL._AC_SX679_.jpg
# Amazon画像ファイル名: エーモン ダブルコード 0.5sq 6m 黒／白ライン E537【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\エーモン ダブルコード 0.5sq 6m 黒／白ライン E537【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 3 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: GUM(ガム) 歯周プロケア 音波振動 アシスト 電動 歯ブラシ ハグキケア毛 替えブラシ #588X 2.6mm 薄型ヘッド
# ヤフオク価格: 957（税込1052）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/u1094319598
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0406/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img134x500-1685863434zcr2eq315568.jpg
# Amazon価格: 1180
# Amazon税金: 0
# Amazon送料: 0／ 6月20日 火曜日にお届け
# Amazon着日: 6月20日火曜日
# Amazon在庫: 残り2点
# Amazon商品URL: https://www.amazon.co.jp/GUM-%E3%82%AC%E3%83%A0-%E3%82%AC%E3%83%A0%E6%AD%AF%E5%91%A8%E3%83%97%E3%83%AD%E3%82%B1%E3%82%A2%E9%9F%B3%E6%B3%A2%E6%8C%AF%E5%8B%95%E3%82%A2%E3%82%B7%E3%82%B9%E3%83%88%E6%9B%BF%E3%83%96%E3%83%A9%E3%82%B7-588X/dp/B07G5BG1RS/ref=sr_1_2?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=3MMGVU1K8WH1&keywords=GUM%28%E3%82%AC%E3%83%A0%29+%E6%AD%AF%E5%91%A8%E3%83%97%E3%83%AD%E3%82%B1%E3%82%A2+%E9%9F%B3%E6%B3%A2%E6%8C%AF%E5%8B%95+%E3%82%A2%E3%82%B7%E3%82%B9%E3%83%88+%E9%9B%BB%E5%8B%95+%E6%AD%AF%E3%83%96%E3%83%A9%E3%82%B7+%E3%83%8F%E3%82%B0%E3%82%AD%E3%82%B1%E3%82%A2%E6%AF%9B+%E6%9B%BF%E3%81%88%E3%83%96%E3%83%A9%E3%82%B7+%23588X+2.6mm+%E8%96%84%E5%9E%8B%E3%83%98%E3%83%83%E3%83%89&qid=1686988094&sprefix=gum+%E3%82%AC%E3%83%A0+%E6%AD%AF%E5%91%A8%2Caps%2C293&sr=8-2
# Amazon画像URL: https://m.media-amazon.com/images/I/71uec2VOQvL._AC_SY879_.jpg
# Amazon画像ファイル名: GUM(ガム) 歯周プロケア 音波振動 アシスト 電動 歯ブラシ ハグキケア毛 替えブラシ #588X 2.6mm 薄型ヘッド【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\GUM(ガム) 歯周プロケア 音波振動 アシスト 電動 歯ブラシ ハグキケア毛 替えブラシ #588X 2.6mm 薄型ヘッド【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 4 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 高儀 斬丸 草刈用 ナイロンコードカッター ベーシック TD-B
# ヤフオク価格: 1172（税込1289）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/q1092444250
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img400x500-1684443069r3ujek67500.jpg
# Amazon価格: 949
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E9%AB%98%E5%84%80-%E8%8D%89%E5%88%88%E7%94%A8-%E3%83%8A%E3%82%A4%E3%83%AD%E3%83%B3%E3%82%B3%E3%83%BC%E3%83%89%E3%82%AB%E3%83%83%E3%82%BF%E3%83%BC-%E3%83%99%E3%83%BC%E3%82%B7%E3%83%83%E3%82%AF-TD-B/dp/B00G8PS2UG/ref=sr_1_5?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E9%AB%98%E5%84%80+%E6%96%AC%E4%B8%B8+%E8%8D%89%E5%88%88+%E3%83%8A%E3%82%A4%E3%83%AD%E3%83%B3%E3%82%B3%E3%83%BC%E3%83%89%E3%82%AB%E3%83%83%E3%82%BF%E3%83%BC+%E3%83%99%E3%83%BC%E3%82%B7%E3%83%83%E3%82%AF+td-b&qid=1686988101&sr=8-5
# Amazon画像URL: https://m.media-amazon.com/images/I/616icontvFL.__AC_SX300_SY300_QL70_ML2_.jpg
# Amazon画像ファイル名: 高儀 斬丸 草刈用 ナイロンコードカッター ベーシック TD-B【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\高儀 斬丸 草刈用 ナイロンコードカッター ベーシック TD-B【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 5 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ホーザン(HOZAN) 合格クリップ 誤接続防止 電気工事士試験の時間短縮に 入数10個 ホルダー付 P-926
# ヤフオク価格: 765（税込841）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/o1095402236
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0406/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x370-16866623192uyknk597848.jpg
# Amazon価格: 500
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）（7 時間 11 分以内にご注文の場合）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%83%9B%E3%83%BC%E3%82%B6%E3%83%B3-HOZAN-%E5%90%88%E6%A0%BC%E3%82%AF%E3%83%AA%E3%83%83%E3%83%97-%E5%9C%A7%E7%9D%80%E4%BD%9C%E6%A5%AD%E5%89%8D%E3%81%AB%E6%8E%A5%E7%B6%9A%E3%81%AE%E4%BA%8B%E5%89%8D%E7%A2%BA%E8%AA%8D%E3%81%8C%E3%81%A7%E3%81%8D%E3%80%81%E8%AA%A4%E6%8E%A5%E7%B6%9A%E3%82%92%E9%98%B2%E3%81%90%E3%81%93%E3%81%A8%E3%81%8C%E3%81%A7%E3%81%8D%E3%82%8B-%E5%85%A5%E6%95%B0/dp/B004WZ6ZHQ/ref=sr_1_2?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=2IAHLGSB7UUMC&keywords=%E3%83%9B%E3%83%BC%E3%82%B6%E3%83%B3%28HOZAN%29+%E5%90%88%E6%A0%BC%E3%82%AF%E3%83%AA%E3%83%83%E3%83%97+%E8%AA%A4%E6%8E%A5%E7%B6%9A%E9%98%B2%E6%AD%A2+%E9%9B%BB%E6%B0%97%E5%B7%A5%E4%BA%8B%E5%A3%AB%E8%A9%A6%E9%A8%93%E3%81%AE%E6%99%82%E9%96%93%E7%9F%AD%E7%B8%AE%E3%81%AB+%E5%85%A5%E6%95%B010%E5%80%8B+%E3%83%9B%E3%83%AB%E3%83%80%E3%83%BC%E4%BB%98+P-926&qid=1686988110&sprefix=%E3%83%9B%E3%83%BC%E3%82%B6%E3%83%B3%2Caps%2C268&sr=8-2
# Amazon画像URL: https://m.media-amazon.com/images/I/51IIS+TUuRL._AC_SX569_.jpg
# Amazon画像ファイル名: ホーザン(HOZAN) 合格クリップ 誤接続防止 電気工事士試験の時間短縮に 入数10個 ホルダー付 P-926【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\ホーザン(HOZAN) 合格クリップ 誤接続防止 電気工事士試験の時間短縮に 入数10個 ホルダー付 P-926【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 6 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 岩崎工業 岩崎 計量 日本製 耐熱 カップ 日本製 メジャー 250ml 樹脂製 K-1557R レッド
# ヤフオク価格: 528（税込580）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/n1085841948
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0403/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x410-1679484570qafl8120021.jpg
# ◆Amazon情報を取得できませんでした。関連画像 ホーザン(HOZAN) 合格クリップ 誤接続防止 電気工事士試験の時間短縮に 入数10個 ホルダー付 P-926【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 7 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: For AQUOS R6 フィルム 覗き見防止 AnnhanT SH-51B TPU フィルム 液晶保護フィルム 24時間自動修復技術 高透過率
# ヤフオク価格: 1560（税込1715）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/m1076558948
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0312/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1671920670wrvxy7172978.jpg
# Amazon価格: 1299
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/AnnhanT-SH-51B-%E6%B6%B2%E6%99%B6%E4%BF%9D%E8%AD%B7%E3%83%95%E3%82%A3%E3%83%AB%E3%83%A0-24%E6%99%82%E9%96%93%E8%87%AA%E5%8B%95%E4%BF%AE%E5%BE%A9%E6%8A%80%E8%A1%93-%E6%9F%94%E8%BB%9F%E6%80%A7TPU%E5%88%B6/dp/B096Y6Y345/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=2OPMVDS4OPUQ3&keywords=For+AQUOS+R6+%E3%83%95%E3%82%A3%E3%83%AB%E3%83%A0+%E8%A6%97%E3%81%8D%E8%A6%8B%E9%98%B2%E6%AD%A2+AnnhanT+SH-51B+TPU+%E3%83%95%E3%82%A3%E3%83%AB%E3%83%A0+%E6%B6%B2%E6%99%B6%E4%BF%9D%E8%AD%B7%E3%83%95%E3%82%A3%E3%83%AB%E3%83%A0+24%E6%99%82%E9%96%93%E8%87%AA%E5%8B%95%E4%BF%AE%E5%BE%A9%E6%8A%80%E8%A1%93+%E9%AB%98%E9%80%8F%E9%81%8E%E7%8E%87&qid=1686988126&sprefix=for+aquos+r6%2Caps%2C368&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/51EOqXiPL8S._AC_SX679_.jpg
# Amazon画像ファイル名: For AQUOS R6 フィルム 覗き見防止 AnnhanT SH-51B TPU フィルム 液晶保護フィルム 24時間自動修復技術 高透過率【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\For AQUOS R6 フィルム 覗き見防止 AnnhanT SH-51B TPU フィルム 液晶保護フィルム 24時間自動修復技術 高透過率【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 8 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ブルーレイディスクレコーダー用リモコン Fit For SONY(ソニー) RMT-B006J代用 BDZ-RS15 BDZ-RX35 BDZ-
# ヤフオク価格: 1811（税込1992）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/q1086414877
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0403/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1679926270strahp11559.jpg
# Amazon価格: 1512
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%83%96%E3%83%AB%E3%83%BC%E3%83%AC%E3%82%A4%E3%83%87%E3%82%A3%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%B3%E3%83%BC%E3%83%80%E3%83%BC%E7%94%A8%E3%83%AA%E3%83%A2%E3%82%B3%E3%83%B3-RMT-B006J%E4%BB%A3%E7%94%A8-BDZ-RS15-BDZ-RX35-BDZ-RX105/dp/B07G14GSM6/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=SE3PZHFO6M18&keywords=%E3%83%96%E3%83%AB%E3%83%BC%E3%83%AC%E3%82%A4%E3%83%87%E3%82%A3%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%B3%E3%83%BC%E3%83%80%E3%83%BC%E7%94%A8%E3%83%AA%E3%83%A2%E3%82%B3%E3%83%B3+Fit+For+SONY%28%E3%82%BD%E3%83%8B%E3%83%BC%29+RMT-B006J%E4%BB%A3%E7%94%A8+BDZ-RS15+BDZ-RX35+BDZ-&qid=1686988134&sprefix=%E3%83%96%E3%83%AB%E3%83%BC%E3%83%AC%E3%82%A4%E3%83%87%E3%82%A3%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%B3%2Caps%2C396&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/61wcA1Ia1DL._AC_SX679_.jpg
# Amazon画像ファイル名: ブルーレイディスクレコーダー用リモコン Fit For SONY(ソニー) RMT-B006J代用 BDZ-RS15 BDZ-RX35 BDZ-【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\ブルーレイディスクレコーダー用リモコン Fit For SONY(ソニー) RMT-B006J代用 BDZ-RS15 BDZ-RX35 BDZ-【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 9 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: レック 激落ち おそうじスリッパ NEO ネイビー S-534
# ヤフオク価格: 735（税込808）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/n1091552485
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1683825749ezjd7c695915.jpg
# Amazon価格: 475
# Amazon税金:
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%83%AC%E3%83%83%E3%82%AF-%E6%BF%80%E8%90%BD%E3%81%A1-%E3%81%8A%E3%81%9D%E3%81%86%E3%81%98%E3%82%B9%E3%83%AA%E3%83%83%E3%83%91-%E3%83%8D%E3%82%A4%E3%83%93%E3%83%BC-S-534/dp/B01GRIO95U/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=1H5AXMXWGJXV3&keywords=%E3%83%AC%E3%83%83%E3%82%AF+%E6%BF%80%E8%90%BD%E3%81%A1+%E3%81%8A%E3%81%9D%E3%81%86%E3%81%98%E3%82%B9%E3%83%AA%E3%83%83%E3%83%91+NEO+%E3%83%8D%E3%82%A4%E3%83%93%E3%83%BC+S-534&qid=1686988143&sprefix=%E3%83%96%E3%83%AB%E3%83%BC%E3%83%AC%E3%82%A4%E3%83%87%E3%82%A3%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%B3%E3%83%BC%E3%83%80%E3%83%BC%E7%94%A8%E3%83%AA%E3%83%A2%E3%82%B3%E3%83%B3+fit+for+sony+%E3%82%BD%E3%83%8B%E3%83%BC+rmt-b006j%E4%BB%A3%E7%94%A8+bdz-rs15+bdz-rx35+bdz-%2Caps%2C460&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/81K33l8y9-L._AC_SX569_.jpg
# Amazon画像ファイル名: レック 激落ち おそうじスリッパ NEO ネイビー S-534【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\レック 激落ち おそうじスリッパ NEO ネイビー S-534【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 10 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: SANEI トイレ部品 万能ロータンクボールタップ スリムタップ マルチタイプ 節水効果 V56-5X-13
# ヤフオク価格: 2617（税込2878）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/l1092899489
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-16848096599h0fuc256526.jpg
# Amazon価格: 2245
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/SANEI-%E6%97%A7%E7%A4%BE%E5%90%8D-%E4%B8%89%E6%A0%84%E6%B0%B4%E6%A0%93%E8%A3%BD%E4%BD%9C%E6%89%80-V56-5X-13-%E4%B8%87%E8%83%BD%E3%83%AD%E3%83%BC%E3%82%BF%E3%83%B3%E3%82%AF%E3%83%9C%E3%83%BC%E3%83%AB%E3%82%BF%E3%83%83%E3%83%97%E3%82%B9%E3%83%AA%E3%83%A0%E3%82%BF%E3%83%83%E3%83%97/dp/B00EU4UG7E/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=39JI0I92XOTWN&keywords=SANEI+%E3%83%88%E3%82%A4%E3%83%AC%E9%83%A8%E5%93%81+%E4%B8%87%E8%83%BD%E3%83%AD%E3%83%BC%E3%82%BF%E3%83%B3%E3%82%AF%E3%83%9C%E3%83%BC%E3%83%AB%E3%82%BF%E3%83%83%E3%83%97+%E3%82%B9%E3%83%AA%E3%83%A0%E3%82%BF%E3%83%83%E3%83%97+%E3%83%9E%E3%83%AB%E3%83%81%E3%82%BF%E3%82%A4%E3%83%97+%E7%AF%80%E6%B0%B4%E5%8A%B9%E6%9E%9C+V56-5X-13&qid=1686988152&sprefix=%E3%83%AC%E3%83%83%E3%82%AF+%E6%BF%80%E8%90%BD%E3%81%A1+%E3%81%8A%E3%81%9D%E3%81%86%E3%81%98%E3%82%B9%E3%83%AA%E3%83%83%E3%83%91+neo+%E3%83%8D%E3%82%A4%E3%83%93%E3%83%BC+s-534%2Caps%2C441&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/41h31y0Nb-L.__AC_SX300_SY300_QL70_ML2_.jpg
# Amazon画像ファイル名: SANEI トイレ部品 万能ロータンクボールタップ スリムタップ マルチタイプ 節水効果 V56-5X-13【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\SANEI トイレ部品 万能ロータンクボールタップ スリムタップ マルチタイプ 節水効果 V56-5X-13【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 11 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ティファール キッチンバサミ 料理ばさみ キッチンシザーズ フレッシュキッチン ナッツクラッカー ボトルオープナー K13441
# ヤフオク価格: 1190（税込1308）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/f1091523575
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x388-1683804072cebz6b396885.jpg
# Amazon価格: 964
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%83%86%E3%82%A3%E3%83%95%E3%82%A1%E3%83%BC%E3%83%AB-%E3%82%AD%E3%83%83%E3%83%81%E3%83%B3%E3%82%B7%E3%82%B6%E3%83%BC%E3%82%BA-%E3%83%95%E3%83%AC%E3%83%83%E3%82%B7%E3%83%A5%E3%82%AD%E3%83%83%E3%83%81%E3%83%B3-%E3%83%8A%E3%83%83%E3%83%84%E3%82%AF%E3%83%A9%E3%83%83%E3%82%AB%E3%83%BC-K13441/dp/B09CY8ZSZS/ref=sr_1_fkmr0_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=3HCDGS3FG5WF1&keywords=%E3%83%86%E3%82%A3%E3%83%95%E3%82%A1%E3%83%BC%E3%83%AB+%E3%82%AD%E3%83%83%E3%83%81%E3%83%B3%E3%83%90%E3%82%B5%E3%83%9F+%E6%96%99%E7%90%86%E3%81%B0%E3%81%95%E3%81%BF+%E3%82%AD%E3%83%83%E3%83%81%E3%83%B3%E3%82%B7%E3%82%B6%E3%83%BC%E3%82%BA+%E3%83%95%E3%83%AC%E3%83%83%E3%82%B7%E3%83%A5%E3%82%AD%E3%83%83%E3%83%81%E3%83%B3+%E3%83%8A%E3%83%83%E3%83%84%E3%82%AF%E3%83%A9%E3%83%83%E3%82%AB%E3%83%BC+%E3%83%9C%E3%83%88%E3%83%AB%E3%82%AA%E3%83%BC%E3%83%97%E3%83%8A%E3%83%BC+K13441&qid=1686988160&sprefix=%E3%83%86%E3%82%A3%E3%83%95%E3%82%A1%E3%83%BC%E3%83%AB+%2Caps%2C323&sr=8-1-fkmr0
# Amazon画像URL: https://m.media-amazon.com/images/I/61x0HB3Q5IL._AC_SX522_.jpg
# Amazon画像ファイル名: ティファール キッチンバサミ 料理ばさみ キッチンシザーズ フレッシュキッチン ナッツクラッカー ボトルオープナー K13441【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\ティファール キッチンバサミ 料理ばさみ キッチンシザーズ フレッシュキッチン ナッツクラッカー ボトルオープナー K13441【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 12 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: シュアラスター 洗車用品 カーワックス クイックワックス タイプ 400ml S-63 クリーナー& カルナバ蝋配合
# ヤフオク価格: 1412（税込1553）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/o1090311988
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0404/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img261x500-1682822210wftgfv368822.jpg
# ◆Amazon情報を取得できませんでした。関連画像 ティファール キッチンバサミ 料理ばさみ キッチンシザーズ フレッシュキッチン ナッツクラッカー ボトルオープナー K13441【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 13 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: Creative Pebble ホワイト USB電源採用アクティブ スピーカー 4.4W パワフル出力 45°上向きドライバー 重低音 パッシブ
# ヤフオク価格: 2693（税込2962）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/q1092653246
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1684603315hpgnbr154114.jpg
# ◆Amazon情報を取得できませんでした。関連画像 ティファール キッチンバサミ 料理ばさみ キッチンシザーズ フレッシュキッチン ナッツクラッカー ボトルオープナー K13441【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 14 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ライオン (LION) ペットキッス (PETKISS) 猫用おやつ ネコちゃんの歯みがきおやつ スティック まぐろ味 4個パック (まとめ買い
# ヤフオク価格: 1049（税込1153）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/g1078638506
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0401/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x463-1673749895ojfkdk118031.jpg
# Amazon価格: 808
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%83%9A%E3%83%83%E3%83%88%E3%82%AD%E3%83%83%E3%82%B9-PETKISS-%E7%8C%AB%E7%94%A8%E3%81%8A%E3%82%84%E3%81%A4-%E3%83%8D%E3%82%B3%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E6%AD%AF%E3%81%BF%E3%81%8C%E3%81%8D%E3%81%8A%E3%82%84%E3%81%A4-%E3%82%B9%E3%83%86%E3%82%A3%E3%83%83%E3%82%AF/dp/B0857XPWF9/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=23JJ58AIZ4O0G&keywords=%E3%83%A9%E3%82%A4%E3%82%AA%E3%83%B3+%28LION%29+%E3%83%9A%E3%83%83%E3%83%88%E3%82%AD%E3%83%83%E3%82%B9+%28PETKISS%29+%E7%8C%AB%E7%94%A8%E3%81%8A%E3%82%84%E3%81%A4+%E3%83%8D%E3%82%B3%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E6%AD%AF%E3%81%BF%E3%81%8C%E3%81%8D%E3%81%8A%E3%82%84%E3%81%A4+%E3%82%B9%E3%83%86%E3%82%A3%E3%83%83%E3%82%AF+%E3%81%BE%E3%81%90%E3%82%8D%E5%91%B3+4%E5%80%8B%E3%83%91%E3%83%83%E3%82%AF+%28%E3%81%BE%E3%81%A8%E3%82%81%E8%B2%B7%E3%81%84&qid=1686988183&sprefix=%E3%83%A9%E3%82%A4%E3%82%AA%E3%83%B3+lion+%E3%83%9A%E3%83%83%E3%83%88%2Caps%2C453&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/71ekpe3jifL._AC_SX425_.jpg
# Amazon画像ファイル名: ライオン (LION) ペットキッス (PETKISS) 猫用おやつ ネコちゃんの歯みがきおやつ スティック まぐろ味 4個パック (まとめ買い【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\ライオン (LION) ペットキッス (PETKISS) 猫用おやつ ネコちゃんの歯みがきおやつ スティック まぐろ味 4個パック (まとめ買い【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 15 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: フォルクスワーゲン PASSAT パサート 8代目 B8 2015+ Valiant ヴァリアント 専用 車用サンシェード フロン
# ヤフオク価格: 4001（税込4401）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/m1087287718
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0404/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-168059590473ao4r317455.jpg
# ◆Amazon情報を取得できませんでした。関連画像 ライオン (LION) ペットキッス (PETKISS) 猫用おやつ ネコちゃんの歯みがきおやつ スティック まぐろ味 4個パック (まとめ買い【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 16 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 【まとめ買い】アリエール 液体 ダニよけプラス 洗濯洗剤 詰め替え 超特大 1.36kg×2個
# ヤフオク価格: 1774（税込1951）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/o1077117502
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0312/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1672398079ld06cl380381.jpg
# Amazon価格: 1572
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%80%90%E3%81%BE%E3%81%A8%E3%82%81%E8%B2%B7%E3%81%84%E3%80%91%E3%82%A2%E3%83%AA%E3%82%A8%E3%83%BC%E3%83%AB-%E3%83%80%E3%83%8B%E3%82%88%E3%81%91%E3%83%97%E3%83%A9%E3%82%B9-%E6%B4%97%E6%BF%AF%E6%B4%97%E5%89%A4-%E8%A9%B0%E3%82%81%E6%9B%BF%E3%81%88-1-36kg%C3%972%E5%80%8B/dp/B084BDBNKP/ref=sr_1_2?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=2QPX22LBZHRE7&keywords=%E3%80%90%E3%81%BE%E3%81%A8%E3%82%81%E8%B2%B7%E3%81%84%E3%80%91%E3%82%A2%E3%83%AA%E3%82%A8%E3%83%BC%E3%83%AB+%E6%B6%B2%E4%BD%93+%E3%83%80%E3%83%8B%E3%82%88%E3%81%91%E3%83%97%E3%83%A9%E3%82%B9+%E6%B4%97%E6%BF%AF%E6%B4%97%E5%89%A4+%E8%A9%B0%E3%82%81%E6%9B%BF%E3%81%88+%E8%B6%85%E7%89%B9%E5%A4%A7+1.36kg%C3%972%E5%80%8B&qid=1686988199&sprefix=%E3%81%BE%E3%81%A8%E3%82%81%E8%B2%B7%E3%81%84+%E3%82%A2%E3%83%AA%E3%82%A8%E3%83%BC%2Caps%2C298&sr=8-2
# Amazon画像URL: https://m.media-amazon.com/images/I/71H09vvndJL._AC_SX679_PIbundle-2,TopRight,0,0_SH20_.jpg
# Amazon画像ファイル名: 【まとめ買い】アリエール 液体 ダニよけプラス 洗濯洗剤 詰め替え 超特大 1.36kg×2個【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\【まとめ買い】アリエール 液体 ダニよけプラス 洗濯洗剤 詰め替え 超特大 1.36kg×2個【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 17 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ORBIS Mr.(オルビス ミスター) ミスター ローション メンズ 化粧水 スキンケア 男性用 詰替え 本体 150ml 1.ローション 2
# ヤフオク価格: 2369（税込2605）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/x1090213804
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0404/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-16827240745penre517625.jpg
# Amazon価格: 1980
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/ORBIS-Mr-%E3%82%AA%E3%83%AB%E3%83%93%E3%82%B9-%E3%83%9F%E3%82%B9%E3%82%BF%E3%83%BC-150%E3%83%9F%E3%83%AA%E3%83%AA%E3%83%83%E3%83%88%E3%83%AB/dp/B08XR82C91/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=2B744RH5J5K34&keywords=ORBIS+Mr.%28%E3%82%AA%E3%83%AB%E3%83%93%E3%82%B9+%E3%83%9F%E3%82%B9%E3%82%BF%E3%83%BC%29+%E3%83%9F%E3%82%B9%E3%82%BF%E3%83%BC+%E3%83%AD%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3+%E3%83%A1%E3%83%B3%E3%82%BA+%E5%8C%96%E7%B2%A7%E6%B0%B4+%E3%82%B9%E3%82%AD%E3%83%B3%E3%82%B1%E3%82%A2+%E7%94%B7%E6%80%A7%E7%94%A8+%E8%A9%B0%E6%9B%BF%E3%81%88+%E6%9C%AC%E4%BD%93+150ml+1.%E3%83%AD%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3+2&qid=1686988206&sprefix=o%2Caps%2C407&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/419rN9QetkL._AC_SX679_.jpg
# Amazon画像ファイル名: ORBIS Mr.(オルビス ミスター) ミスター ローション メンズ 化粧水 スキンケア 男性用 詰替え 本体 150ml 1.ローション 2【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\ORBIS Mr.(オルビス ミスター) ミスター ローション メンズ 化粧水 スキンケア 男性用 詰替え 本体 150ml 1.ローション 2【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 18 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 100mm ダクト用換気扇 ブースターファン静音インラインダクト通気用送風機、ダクト、通気口、育成用テントでの空調用排気
# ヤフオク価格: 2392（税込2631）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/j1094550824
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0406/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1686038333xmn8ds393961.jpg
# Amazon価格: 1999
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 残り15点
# Amazon商品URL: https://www.amazon.co.jp/SAIFLO-100mm-%E3%83%80%E3%82%AF%E3%83%88%E7%94%A8%E6%8F%9B%E6%B0%97%E6%89%87-%E3%83%96%E3%83%BC%E3%82%B9%E3%82%BF%E3%83%BC%E3%83%95%E3%82%A1%E3%83%B3%E9%9D%99%E9%9F%B3%E3%82%A4%E3%83%B3%E3%83%A9%E3%82%A4%E3%83%B3%E3%83%80%E3%82%AF%E3%83%88%E9%80%9A%E6%B0%97%E7%94%A8%E9%80%81%E9%A2%A8%E6%A9%9F%E3%80%81%E3%83%80%E3%82%AF%E3%83%88%E3%80%81%E9%80%9A%E6%B0%97%E5%8F%A3%E3%80%81%E8%82%B2%E6%88%90%E7%94%A8%E3%83%86%E3%83%B3%E3%83%88%E3%81%A7%E3%81%AE%E7%A9%BA%E8%AA%BF%E7%94%A8%E6%8E%92%E6%B0%97/dp/B07FYK5JKC/ref=sr_1_1_sspa?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=3694WU71ECW8E&keywords=100mm+%E3%83%80%E3%82%AF%E3%83%88%E7%94%A8%E6%8F%9B%E6%B0%97%E6%89%87+%E3%83%96%E3%83%BC%E3%82%B9%E3%82%BF%E3%83%BC%E3%83%95%E3%82%A1%E3%83%B3%E9%9D%99%E9%9F%B3%E3%82%A4%E3%83%B3%E3%83%A9%E3%82%A4%E3%83%B3%E3%83%80%E3%82%AF%E3%83%88%E9%80%9A%E6%B0%97%E7%94%A8%E9%80%81%E9%A2%A8%E6%A9%9F%E3%80%81%E3%83%80%E3%82%AF%E3%83%88%E3%80%81%E9%80%9A%E6%B0%97%E5%8F%A3%E3%80%81%E8%82%B2%E6%88%90%E7%94%A8%E3%83%86%E3%83%B3%E3%83%88%E3%81%A7%E3%81%AE%E7%A9%BA%E8%AA%BF%E7%94%A8%E6%8E%92%E6%B0%97&qid=1686988215&sprefix=%2Caps%2C331&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1
# Amazon画像URL: https://m.media-amazon.com/images/I/51Kv4J3hlPL._AC_SX569_.jpg
# Amazon画像ファイル名: 100mm ダクト用換気扇 ブースターファン静音インラインダクト通気用送風機、ダクト、通気口、育成用テントでの空調用排気【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\100mm ダクト用換気扇 ブースターファン静音インラインダクト通気用送風機、ダクト、通気口、育成用テントでの空調用排気【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 19 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: CYBER ・ ダブルスタイルコントローラー （ SWITCH 用）ホワイト - Switch
# ヤフオク価格: 3274（税込3601）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/q1077470610
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0401/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1672784889w2yqcu515958.jpg
# Amazon価格: 2993
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/CYBER-%E3%83%80%E3%83%96%E3%83%AB%E3%82%B9%E3%82%BF%E3%82%A4%E3%83%AB%E3%82%B3%E3%83%B3%E3%83%88%E3%83%AD%E3%83%BC%E3%83%A9%E3%83%BC-SWITCH-%E7%94%A8%EF%BC%89%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88-Switch/dp/B08VJQKD5N/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=1CIWTZS9S9978&keywords=CYBER+%E3%83%BB+%E3%83%80%E3%83%96%E3%83%AB%E3%82%B9%E3%82%BF%E3%82%A4%E3%83%AB%E3%82%B3%E3%83%B3%E3%83%88%E3%83%AD%E3%83%BC%E3%83%A9%E3%83%BC+%EF%BC%88+SWITCH+%E7%94%A8%EF%BC%89%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88+-+Switch&qid=1686988223&sprefix=%2Caps%2C274&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/61wh3D1P7TL.__AC_SX300_SY300_QL70_ML2_.jpg
# Amazon画像ファイル名: CYBER ・ ダブルスタイルコントローラー （ SWITCH 用）ホワイト - Switch【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\CYBER ・ ダブルスタイルコントローラー （ SWITCH 用）ホワイト - Switch【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 20 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: JEJアステージ 収納ボックス 日本製 積み重ね [Xシリーズ NTボックス #13] 幅29.5×奥行44×高さ16cm
# ヤフオク価格: 1237（税込1360）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/h1083132042
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0402/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x373-167739968354u2hp523911.jpg
# Amazon価格: 12255
# Amazon税金: 0
# Amazon送料: 0／ 6月20日 火曜日にお届け
# Amazon着日: 6月20日火曜日
# Amazon在庫: 残り20点
# Amazon商品URL: https://www.amazon.co.jp/JEJ%E3%82%A2%E3%82%B9%E3%83%86%E3%83%BC%E3%82%B8-%E5%8F%8E%E7%B4%8D%E3%83%9C%E3%83%83%E3%82%AF%E3%82%B9-NT%E3%83%9C%E3%83%83%E3%82%AF%E3%82%B9-%E5%B9%8529-5%C3%97%E5%A5%A5%E8%A1%8C44%C3%97%E9%AB%98%E3%81%9516cm-10%E5%80%8B%E3%82%BB%E3%83%83%E3%83%88/dp/B09T2LM5Q9/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=3701ULKGXMSVM&keywords=JEJ%E3%82%A2%E3%82%B9%E3%83%86%E3%83%BC%E3%82%B8+%E5%8F%8E%E7%B4%8D%E3%83%9C%E3%83%83%E3%82%AF%E3%82%B9+%E6%97%A5%E6%9C%AC%E8%A3%BD+%E7%A9%8D%E3%81%BF%E9%87%8D%E3%81%AD+%5BX%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA+NT%E3%83%9C%E3%83%83%E3%82%AF%E3%82%B9+%2313%5D+%E5%B9%8529.5%C3%97%E5%A5%A5%E8%A1%8C44%C3%97%E9%AB%98%E3%81%9516cm&qid=1686988232&sprefix=jej%E3%82%A2%E3%82%B9%E3%83%86%2Caps%2C495&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/61nNG7vVAXL._AC_SX569_.jpg
# Amazon画像ファイル名: JEJアステージ 収納ボックス 日本製 積み重ね [Xシリーズ NTボックス #13] 幅29.5×奥行44×高さ16cm【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\JEJアステージ 収納ボックス 日本製 積み重ね [Xシリーズ NTボックス #13] 幅29.5×奥行44×高さ16cm【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 21 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: 朝日電器 ELPA 冷蔵庫製氷機用 浄水フィルター 日立用 RJK-30H ホワイト
# ヤフオク価格: 1615（税込1776）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/r1093366074
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1685139876jcx2n784162.jpg
# ◆Amazon情報を取得できませんでした。関連画像 JEJアステージ 収納ボックス 日本製 積み重ね [Xシリーズ NTボックス #13] 幅29.5×奥行44×高さ16cm【ヤフオク】.jpg を削除しました◆
# ■■■■■■■■■■■■■■■ 22 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: SUNHOO 防虫ネット 防虫シート 防虫網 プランター 虫除けネット ガーデニング 家庭菜園 畑 野菜 園芸 農業資材 (3m x 10m)
# ヤフオク価格: 3203（税込3523）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/e1093858804
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1685506898fu4b1l200689.jpg
# Amazon価格: 2799
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/SUNHOO-%E9%98%B2%E8%99%AB%E3%83%8D%E3%83%83%E3%83%88-%E9%98%B2%E8%99%AB%E3%82%B7%E3%83%BC%E3%83%88-%E8%99%AB%E9%99%A4%E3%81%91%E3%83%8D%E3%83%83%E3%83%88-%E3%82%AC%E3%83%BC%E3%83%87%E3%83%8B%E3%83%B3%E3%82%B0/dp/B07GTJ2CP4/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=1IWHCBT6FI81X&keywords=SUNHOO+%E9%98%B2%E8%99%AB%E3%83%8D%E3%83%83%E3%83%88+%E9%98%B2%E8%99%AB%E3%82%B7%E3%83%BC%E3%83%88+%E9%98%B2%E8%99%AB%E7%B6%B2+%E3%83%97%E3%83%A9%E3%83%B3%E3%82%BF%E3%83%BC+%E8%99%AB%E9%99%A4%E3%81%91%E3%83%8D%E3%83%83%E3%83%88+%E3%82%AC%E3%83%BC%E3%83%87%E3%83%8B%E3%83%B3%E3%82%B0+%E5%AE%B6%E5%BA%AD%E8%8F%9C%E5%9C%92+%E7%95%91+%E9%87%8E%E8%8F%9C+%E5%9C%92%E8%8A%B8+%E8%BE%B2%E6%A5%AD%E8%B3%87%E6%9D%90+%283m+x+10m%29&qid=1686988251&sprefix=sunhoo+%E9%98%B2%E8%99%AB%E3%83%8D%E3%83%83%E3%83%88+%E9%98%B2%E8%99%AB%E3%82%B7%E3%83%BC%E3%83%88+%E9%98%B2%E8%99%AB%E7%B6%B2+%E3%83%97%E3%83%A9%E3%83%B3%E3%82%BF%2Caps%2C657&sr=8-1
# Amazon画像URL: https://m.media-amazon.com/images/I/5136AyHKt6L._AC_SX569_.jpg
# Amazon画像ファイル名: SUNHOO 防虫ネット 防虫シート 防虫網 プランター 虫除けネット ガーデニング 家庭菜園 畑 野菜 園芸 農業資材 (3m x 10m)【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\SUNHOO 防虫ネット 防虫シート 防虫網 プランター 虫除けネット ガーデニング 家庭菜園 畑 野菜 園芸 農業資材 (3m x 10m)【Amazon】.jpg
# ■■■■■■■■■■■■■■■ 23 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: ネスカフェ ゴールドブレンド コク深め エコ&システムパック (95g×2本)【95杯分】【詰め替え用】
# ヤフオク価格: 1960（税込2156）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/v1093299901
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img500x500-1685071745o4kjit64831.jpg
# Amazon価格: 1636
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%80%90Amazon-co-jp%E9%99%90%E5%AE%9A%E3%80%91-%E3%83%8D%E3%82%B9%E3%82%AB%E3%83%95%E3%82%A7-%E3%82%B4%E3%83%BC%E3%83%AB%E3%83%89%E3%83%96%E3%83%AC%E3%83%B3%E3%83%89-%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0%E3%83%91%E3%83%83%E3%82%AF-95g%C3%972%E6%9C%AC%E3%82%BB%E3%83%83%E3%83%88/dp/B0B2ZTNVKK/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=3U3LBNNH9UZ21&keywords=%E3%83%8D%E3%82%B9%E3%82%AB%E3%83%95%E3%82%A7+%E3%82%B4%E3%83%BC%E3%83%AB%E3%83%89%E3%83%96%E3%83%AC%E3%83%B3%E3%83%89+%E3%82%B3%E3%82%AF%E6%B7%B1%E3%82%81+%E3%82%A8%E3%82%B3%26%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0%E3%83%91%E3%83%83%E3%82%AF+%2895g%C3%972%E6%9C%AC%29%E3%80%9095%E6%9D%AF%E5%88%86%E3%80%91%E3%80%90%E8%A9%B0%E3%82%81%E6%9B%BF%E3%81%88%E7%94%A8%E3%80%91&qid=1686988264&sprefix=%E3%83%8D%E3%82%B9%E3%82%AB%E3%83%95%E3%82%A7+%E3%82%B4%E3%83%BC%E3%83%AB%E3%83%89%E3%83%96%E3%83%AC%E3%83%B3%E3%83%89+%E3%82%B3%E3%82%AF%E6%B7%B1%2Caps%2C611&sr=8-1
# Amazon画像URL: ◆取得失敗◆
# Amazon画像ファイル名: ◆取得失敗◆
# Amazon画像ファイルパス: ◆取得失敗◆
# ◆Amazon情報を取得できませんでした。関連画像 ◆取得失敗◆ を削除しました◆
# ■■■■■■■■■■■■■■■ 24 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: コネクター2極 3極 4極 RMS 防水 カプラー 配線用? オス＆メス 防水コネクタ 防水電気端子 車防水電線コネクタ オートバイク 自動車
# ヤフオク価格: 1243（税込1367）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/j1089554330
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0404/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img482x500-1682264328irozsa521307.jpg
# ◆Amazon情報を取得できませんでした。関連画像 ◆取得失敗◆ を削除しました◆
# ■■■■■■■■■■■■■■■ 25 / 25 ■■■■■■■■■■■■■■■
# ヤフオク商品名: コミネ(KOMINE) バイク用 コミネCEプロテクターE/K フリー SK-635 CE規格
# ヤフオク価格: 1285（税込1413）
# ヤフオク税金: 0
# ヤフオク送料: 0（税込）
# ヤフオク入札件数: 1
# ヤフオク評価日: 1週間以内
# ヤフオク商品URL: https://page.auctions.yahoo.co.jp/jp/auction/r1093299984
# ヤフオク商品URL: https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0405/users/4ab9d116d8c2795dea9bae6aaeee32f248682eb3/i-img497x500-1685084131g3o22b65938.jpg
# Amazon価格: 1059
# Amazon税金: 0
# Amazon送料: 0／ 6月19日 月曜日にお届け（初回注文特典）
# Amazon着日: 6月19日月曜日
# Amazon在庫: 在庫あり
# Amazon商品URL: https://www.amazon.co.jp/%E3%82%B3%E3%83%9F%E3%83%8D-Komine-%E3%81%B2%E3%81%96%E3%81%99%E3%81%AD%E3%83%97%E3%83%AD%E3%83%86%E3%82%AF%E3%82%BF%E3%83%BC-%E3%82%B3%E3%83%9F%E3%83%8DCE%E3%83%97%E3%83%AD%E3%83%86%E3%82%AF%E3%82%BF%E3%83%BC%E3%82%A8%E3%83%AB%E3%83%9C%E3%83%BC-04-635/dp/B00DDTFRRQ/ref=sr_1_2_sspa?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=18YC8L8WZ5UZA&keywords=%E3%82%B3%E3%83%9F%E3%83%8D%28KOMINE%29+%E3%83%90%E3%82%A4%E3%82%AF%E7%94%A8+%E3%82%B3%E3%83%9F%E3%83%8DCE%E3%83%97%E3%83%AD%E3%83%86%E3%82%AF%E3%82%BF%E3%83%BCE%2FK+%E3%83%95%E3%83%AA%E3%83%BC+SK-635+CE%E8%A6%8F%E6%A0%BC&qid=1686988280&sprefix=%E3%82%B3%E3%83%9F%E3%83%8D+komin%2Caps%2C304&sr=8-2-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1
# Amazon画像URL: https://m.media-amazon.com/images/I/71FR0ic-FLL._AC_SX679_.jpg
# Amazon画像ファイル名: コミネ(KOMINE) バイク用 コミネCEプロテクターE／K フリー SK-635 CE規格【Amazon】.jpg
# Amazon画像ファイルパス: C:\Users\amuza\OneDrive\Documents\Python-study\ec_scraping\amazon_to_yafuoku_images\コミネ(KOMINE) バイク用 コミネCEプロテクターE／K フリー SK-635 CE規格【Amazon】.jpg
# ----- Amazon情報取得完了 -----
# Wall time: 3min 32s
